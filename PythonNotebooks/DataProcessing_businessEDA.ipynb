# %%
import pandas as pd
import io

# %%
#Read CSV file to Pandas dataframe and normalize all the columns

df = pd.read_csv('https://raw.githubusercontent.com/NhatMinh2910/Business-Sales-Analyzing/refs/heads/main/Business_sales_EDA.csv')

df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
)

df.head()
# Out:
#    product_id product_position promotion product_category seasonal  \
# 0      185102            Aisle       Yes         clothing      Yes
# 1      188771            Aisle       Yes         clothing       No
# 2      180176          End-cap       Yes         clothing      Yes
# 3      112917            Aisle       Yes         clothing       No
# 4      192936          End-cap       Yes         clothing      Yes
#
#    sales_volume brand                                                url  \
# 0          1243  Zara  https://www.zara.com/us/en/basic-puffer-jacket...
# 1          1429  Zara  https://www.zara.com/us/en/tuxedo-jacket-p0889...
# 2          1168  Zara  https://www.zara.com/us/en/slim-fit-suit-jacke...
# 3          1348  Zara  https://www.zara.com/us/en/stretch-suit-jacket...
# 4          1602  Zara  https://www.zara.com/us/en/double-faced-jacket...
#
#                    name                                        description  \
# 0   BASIC PUFFER JACKET  Puffer jacket made of tear-resistant ripstop f...
# 1         TUXEDO JACKET  Straight fit blazer. Pointed lapel collar and ...
# 2  SLIM FIT SUIT JACKET  Slim fit jacket. Notched lapel collar. Long sl...
# 3   STRETCH SUIT JACKET  Slim fit jacket made of viscose blend fabric. ...
# 4   DOUBLE FACED JACKET  Jacket made of faux leather faux shearling wit...
#
#    price currency    terms section  season    material   origin
# 0  78.99      USD  jackets     MAN  Winter   Polyester   Brazil
# 1  14.99      USD  jackets     MAN  Autumn      Cotton   Turkey
# 2  71.95      USD  jackets   WOMAN  Autumn   Polyester  Morocco
# 3  30.99      USD  jackets     MAN  Spring   Polyester    China
# 4  22.99      USD  jackets   WOMAN  Winter  Wool Blend    China

# %% [markdown]
# # **Categorize columns**
#
# ---
#
#
#
# *   **'product_id'** - Identifier
# * **'product_position'** - Position/ Exposure
# * **'promotion', 'seasonal'** - Promotion/ Marketing
# * **'product_category', 'name', 'description', 'terms', 'brand', 'material', 'origin', 'section'** - Product Information
# * **'sales_volume', 'price', 'currency'** - Sales Metrics
# *  **'season', 'url'** - Metadata

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20252 entries, 0 to 20251
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_id        20252 non-null  int64
#  1   product_position  20252 non-null  object
#  2   promotion         20252 non-null  object
#  3   product_category  20252 non-null  object
#  4   seasonal          20252 non-null  object
#  5   sales_volume      20252 non-null  int64
#  6   brand             20252 non-null  object
#  7   url               20252 non-null  object
#  8   name              20251 non-null  object
#  9   description       20250 non-null  object
#  10  price             20252 non-null  float64
#  11  currency          20252 non-null  object
#  12  terms             20252 non-null  object
#  13  section           20252 non-null  object
#  14  season            20252 non-null  object
#  15  material          20252 non-null  object
#  16  origin            20252 non-null  object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 2.6+ MB

# %%
df["sales_volume"] = pd.to_numeric(df["sales_volume"], errors="coerce")
df["price"] = pd.to_numeric(df["price"], errors="coerce")

# %%
df.isnull().mean().sort_values(ascending=False)
# Out:
# description         0.000099
# name                0.000049
# product_id          0.000000
# product_category    0.000000
# product_position    0.000000
# seasonal            0.000000
# sales_volume        0.000000
# brand               0.000000
# promotion           0.000000
# url                 0.000000
# price               0.000000
# currency            0.000000
# terms               0.000000
# section             0.000000
# season              0.000000
# material            0.000000
# origin              0.000000
# dtype: float64

# %% [markdown]
# # **Strategies in handling missing values**
#
# ---
#
#
# *   product_id: Do not accept missing value -> Drop row
# * sales_volume: Fill with 0
# * price: Fill with category median
# * brand: Fill "Unknown"
# * material/ origin: Fill with "Not specified"

# %%
df = df.dropna(subset=["product_id"])
df["brand"] = df["brand"].fillna("Unknown")
df["material"] = df["material"].fillna("Not specified")

# %%
#Check for productID duplicates (Drop if there are any duplicates)
df["product_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
#Validate numeric features
#Sales & Price must be > 0
df = df[df["sales_volume"] > 0]
df = df[df["price"] > 0]
#Look for any outlier
df["price"].describe()
df["sales_volume"].describe()
# Out:
# count    20252.000000
# mean      1097.400454
# std        298.234609
# min        518.000000
# 25%        849.000000
# 50%        990.000000
# 75%       1364.250000
# max       1940.000000
# Name: sales_volume, dtype: float64

# %%
#Normalize Promotion and Seasonal values to boolean values
df["promotion"].value_counts()
df["seasonal"].value_counts()
df["promotion"] = df["promotion"].str.lower().isin(["yes", "true", "1"])
df["seasonal"] = df["seasonal"].str.lower().isin(["yes", "true", "1"])
df.head(10)
# Out:
#    product_id product_position  promotion product_category  seasonal  \
# 0      185102            Aisle       True         clothing      True
# 1      188771            Aisle       True         clothing     False
# 2      180176          End-cap       True         clothing      True
# 3      112917            Aisle       True         clothing     False
# 4      192936          End-cap       True         clothing      True
# 5      117590          End-cap       True         clothing      True
# 6      189118   Front of Store      False         clothing     False
# 7      182157            Aisle       True         clothing      True
# 8      141861            Aisle      False         clothing      True
# 9      137121            Aisle      False         clothing     False
#
#    sales_volume brand                                                url  \
# 0          1243  Zara  https://www.zara.com/us/en/basic-puffer-jacket...
# 1          1429  Zara  https://www.zara.com/us/en/tuxedo-jacket-p0889...
# 2          1168  Zara  https://www.zara.com/us/en/slim-fit-suit-jacke...
# 3          1348  Zara  https://www.zara.com/us/en/stretch-suit-jacket...
# 4          1602  Zara  https://www.zara.com/us/en/double-faced-jacket...
# 5          1282  Zara  https://www.zara.com/us/en/contrasting-collar-...
# 6           688  Zara  https://www.zara.com/us/en/faux-leather-puffer...
# 7          1711  Zara  https://www.zara.com/us/en/suit-jacket-in-100-...
# 8           857  Zara  https://www.zara.com/us/en/100-wool-suit-jacke...
# 9           769  Zara  https://www.zara.com/us/en/100-feather-fill-pu...
#
#                               name  \
# 0              BASIC PUFFER JACKET
# 1                    TUXEDO JACKET
# 2             SLIM FIT SUIT JACKET
# 3              STRETCH SUIT JACKET
# 4              DOUBLE FACED JACKET
# 5        CONTRASTING COLLAR JACKET
# 6       FAUX LEATHER PUFFER JACKET
# 7        SUIT JACKET IN 100% LINEN
# 8            100% WOOL SUIT JACKET
# 9  100% FEATHER FILL PUFFER JACKET
#
#                                          description  price currency    terms  \
# 0  Puffer jacket made of tear-resistant ripstop f...  78.99      USD  jackets
# 1  Straight fit blazer. Pointed lapel collar and ...  14.99      USD  jackets
# 2  Slim fit jacket. Notched lapel collar. Long sl...  71.95      USD  jackets
# 3  Slim fit jacket made of viscose blend fabric. ...  30.99      USD  jackets
# 4  Jacket made of faux leather faux shearling wit...  22.99      USD  jackets
# 5  Relaxed fit jacket. Contrasting lapel collar a...  25.95      USD  jackets
# 6  Faux leather puffer jacket. High collar and lo...  87.99      USD  jackets
# 7  Straight fit blazer made of linen. Notched lap...  24.00      USD  jackets
# 8  Jacket made of Italian wool. Pointed lapel col...  32.95      USD  jackets
# 9  Puffer jacket made of shiny finish technical f...  39.95      USD  jackets
#
#   section  season    material    origin
# 0     MAN  Winter   Polyester    Brazil
# 1     MAN  Autumn      Cotton    Turkey
# 2   WOMAN  Autumn   Polyester   Morocco
# 3     MAN  Spring   Polyester     China
# 4   WOMAN  Winter  Wool Blend     China
# 5   WOMAN  Autumn      Cotton    Turkey
# 6     MAN  Winter     Acrylic     China
# 7   WOMAN  Summer      Cotton  Portugal
# 8   WOMAN  Winter        Wool     India
# 9     MAN  Autumn  Wool Blend     China

# %%
#Categorical cleaning (Product Category, Brand, Section, Season) - Change all string to lowercase
cat_cols = ["product_category", "brand", "section", "season"]

for col in cat_cols:
    df[col] = df[col].str.lower().str.strip()

# %%
#Check if there are any different currencies used
df["currency"].value_counts()
# Out:
# currency
# USD    20252
# Name: count, dtype: int64

# %%
#Export the final processed dataset to a new csv file
df.to_csv("Business-sales-EDA-processed.csv", index=False)
